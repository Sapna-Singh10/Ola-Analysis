# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Bookings.csv')

# %%
df.head(5)
# Out:
#          Date      Time Booking ID         Booking Status Customer ID  \
# 0  04-01-2024  10:30:00  BLR472042    Cancelled by Driver   CUST85100
# 1  26-01-2024  18:00:00  BLR839110    Cancelled by Driver   CUST18631
# 2  08-01-2024  15:00:00  BLR114776             Incomplete   CUST40633
# 3  30-01-2024  16:15:00  BLR804774  Cancelled by Customer   CUST30251
# 4  05-01-2024  14:15:00  BLR285027                Success   CUST78912
#
#   Vehicle Type Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0         Auto        Horamavu             Ulsoor       NaN       NaN
# 1  Prime Sedan    Marathahalli        Sanjaynagar       NaN       NaN
# 2        eBike         Kengeri  Basaveshwaranagar       NaN       NaN
# 3         Mini     Koramangala       Malleshwaram       NaN       NaN
# 4        eBike        Horamavu       Bommanahalli       2.5       6.3
#
#    Cancelled Rides by Customer             Reason for Cancelling by Customer  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               100000 non-null  object
#  1   Time                               100000 non-null  object
#  2   Booking ID                         100000 non-null  object
#  3   Booking Status                     100000 non-null  object
#  4   Customer ID                        100000 non-null  object
#  5   Vehicle Type                       100000 non-null  object
#  6   Pickup Location                    100000 non-null  object
#  7   Drop Location                      100000 non-null  object
#  8   Avg VTAT                           62122 non-null   float64
#  9   Avg CTAT                           62122 non-null   float64
#  10  Cancelled Rides by Customer        100000 non-null  int64
# ...

# %%
df.isnull()
# Out:
#         Date   Time  Booking ID  Booking Status  Customer ID  Vehicle Type  \
# 0      False  False       False           False        False         False
# 1      False  False       False           False        False         False
# 2      False  False       False           False        False         False
# 3      False  False       False           False        False         False
# 4      False  False       False           False        False         False
# ...      ...    ...         ...             ...          ...           ...
# 99995  False  False       False           False        False         False
# 99996  False  False       False           False        False         False
# 99997  False  False       False           False        False         False
# 99998  False  False       False           False        False         False
# 99999  False  False       False           False        False         False
#
#        Pickup Location  Drop Location  Avg VTAT  Avg CTAT  \
# ...

# %%
df.fillna(pd.NA)
# Out:
#              Date      Time Booking ID         Booking Status Customer ID  \
# 0      04-01-2024  10:30:00  BLR472042    Cancelled by Driver   CUST85100
# 1      26-01-2024  18:00:00  BLR839110    Cancelled by Driver   CUST18631
# 2      08-01-2024  15:00:00  BLR114776             Incomplete   CUST40633
# 3      30-01-2024  16:15:00  BLR804774  Cancelled by Customer   CUST30251
# 4      05-01-2024  14:15:00  BLR285027                Success   CUST78912
# ...           ...       ...        ...                    ...         ...
# 99995  28-01-2024   9:30:00  BLR874366                Success   CUST61525
# 99996  25-01-2024   1:45:00  BLR528407                Success   CUST66139
# 99997  16-01-2024   7:30:00  BLR436237    Cancelled by Driver   CUST73757
# 99998  21-01-2024  10:00:00  BLR729466                Success   CUST19718
# 99999  10-01-2024   2:30:00  BLR122388                Success   CUST71942
#
#       Vehicle Type Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# ...
